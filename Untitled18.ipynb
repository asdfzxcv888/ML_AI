# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import os
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'

# %%
import tf_keras

# %%
print(tf.__version__)
print(hub.__version__)
IMAGE_SHAPE=(224,224)
# Out:
# 2.19.0
# 0.16.1

# %%
mobilenet_v2_layer = hub.KerasLayer(
    "https://tfhub.dev/google/tf2-preview/mobilenet_v2/classification/4",
    input_shape=IMAGE_SHAPE + (3,),
    trainable=False  # Set to True if you want to fine-tune
)
# Out:
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# ...

# %%
# Create the Sequential model correctly
classifier = tf_keras.Sequential([
    mobilenet_v2_layer
])

# %%
import tf_keras

# %%
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url,  cache_dir='.', untar=True)
# cache_dir indicates where to download data. I specified . which means current directory
# Out:
# ...
# 228813984/228813984 ━━━━━━━━━━━━━━━━━━━━ 23s 0us/step

# %%
data_dir
# Out:
# '.\\datasets\\flower_photos'

# %%
import pathlib

# %%
data_dir
# Out:
# '.\\datasets\\flower_photos'

# %%
data_dir =  './datasets/flower_photos/flower_photos'

# %%
data_dir
# Out:
# './datasets/flower_photos/flower_photos'

# %%
import pathlib
data_dir = pathlib.Path(data_dir)

list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [WindowsPath('datasets/flower_photos/flower_photos/daisy/100080576_f52e8ee070_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10140303196_b88d3d6cec.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10172379554_b296050f82_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10172567486_2748826a8b.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/daisy/10172636503_21bededa75_n.jpg')]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 3670

# %%
roses = list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [WindowsPath('datasets/flower_photos/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/110472418_87b6a3aa98_m.jpg')]

# %%
flowers_images_dict = {
    'roses': list(data_dir.glob('roses/*')),
    'daisy': list(data_dir.glob('daisy/*')),
    'dandelion': list(data_dir.glob('dandelion/*')),
    'sunflowers': list(data_dir.glob('sunflowers/*')),
    'tulips': list(data_dir.glob('tulips/*')),
}

# %%
flowers_images_dict['roses']
# Out:
# [WindowsPath('datasets/flower_photos/flower_photos/roses/10090824183_d02c613f10_m.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/102501987_3cdb8e5394_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10503217854_e66a804309.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/10894627425_ec76bbc757_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/110472418_87b6a3aa98_m.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/11102341464_508d558dfc_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/11233672494_d8bf0a3dbf_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/11694025703_9a906fedc1_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/118974357_0faa23cce9_n.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/11944957684_2cc806276e.jpg'),
#  WindowsPath('datasets/flower_photos/flower_photos/roses/12045735155_42547ce4e9_n.jpg'),
# ...

# %%
flowers_labels_dict = {
    'roses': 0,
    'daisy': 1,
    'dandelion': 2,
    'sunflowers': 3,
    'tulips': 4,
}

# %%
str(flowers_images_dict['roses'][0])
# Out:
# 'datasets\\flower_photos\\flower_photos\\roses\\10090824183_d02c613f10_m.jpg'

# %%
img=cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img
# Out:
# array([[[ 38,  27,  23],
#         [ 41,  26,  23],
#         [ 38,  23,  21],
#         ...,
#         [ 40,  43,  47],
#         [ 41,  44,  48],
#         [ 42,  45,  49]],
#
#        [[ 38,  33,  32],
#         [ 44,  32,  30],
#         [ 45,  31,  32],
#         ...,
#         [ 51,  56,  59],
#         [ 51,  56,  59],
#         [ 52,  57,  60]],
#
#        [[ 37,  35,  34],
#         [ 38,  33,  32],
#         [ 45,  35,  35],
#         ...,
#         [ 48,  54,  59],
#         [ 47,  53,  58],
#         [ 48,  54,  59]],
#
#        ...,
#
#        [[ 70,  78, 148],
#         [ 64,  73, 141],
#         [ 57,  65, 132],
#         ...,
#         [ 82,  73,  69],
#         [ 84,  75,  72],
#         [ 84,  75,  72]],
#
#        [[ 64,  72, 142],
#         [ 67,  76, 144],
#         [ 64,  72, 139],
#         ...,
#         [ 79,  67,  63],
#         [ 75,  63,  59],
#         [ 72,  60,  56]],
#
#        [[ 51,  53, 124],
#         [ 64,  71, 140],
#         [ 59,  70, 138],
# ...

# %%
img.shape
# Out:
# (241, 320, 3)

# %%
cv2.resize(img,(224,224)).shape
# Out:
# (224, 224, 3)

# %%
X, y = [], []

for flowerimage,images in flowers_images_dict.items():
  for image in images:
    img = cv2.imread(str(image))
    resized=cv2.resize(img,(224,224))
    X.append(resized)
    y.append(flowers_labels_dict[flowerimage])

# %%
k=np.array(X)
k=k/255
k
# Out:
# array([[[[0.        , 0.05882353, 0.02352941],
#          [0.        , 0.05882353, 0.02352941],
#          [0.        , 0.0627451 , 0.02745098],
#          ...,
#          [0.09411765, 0.2       , 0.12156863],
#          [0.09803922, 0.20392157, 0.1254902 ],
#          [0.10196078, 0.20784314, 0.12941176]],
#
#         [[0.03137255, 0.08627451, 0.05490196],
#          [0.03137255, 0.08627451, 0.05490196],
#          [0.02745098, 0.08235294, 0.05490196],
#          ...,
#          [0.08235294, 0.18431373, 0.12156863],
#          [0.09411765, 0.19215686, 0.13333333],
#          [0.09803922, 0.2       , 0.1372549 ]],
#
#         [[0.04705882, 0.08627451, 0.05882353],
#          [0.04705882, 0.08627451, 0.05882353],
#          [0.04313725, 0.08627451, 0.05490196],
#          ...,
#          [0.08235294, 0.16862745, 0.12156863],
#          [0.09411765, 0.18039216, 0.12941176],
#          [0.10196078, 0.18823529, 0.14117647]],
#
#         ...,
#
# ...

# %%
X=k

# %%
y=np.array(y)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
X_train[0].shape
# Out:
# (224, 224, 3)

# %%
feature_extractor_model = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

pretrained_model_without_top_layer = hub.KerasLayer(
    feature_extractor_model, input_shape=(224, 224, 3), trainable=False)

# %%
num_of_flowers = 5

model = tf_keras.Sequential([
  pretrained_model_without_top_layer,
  tf_keras.layers.Dense(num_of_flowers)
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_1 (KerasLayer)  (None, 1280)              2257984
#
#  dense (Dense)               (None, 5)                 6405
#
# ...
# Total params: 2264389 (8.64 MB)
# Trainable params: 6405 (25.02 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
  optimizer="adam",
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['acc'])

model.fit(X_train, y_train, epochs=5)
# Out:
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tf_keras\src\optimizers\__init__.py:317: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tf_keras\src\optimizers\__init__.py:317: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# Epoch 1/5
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\M.ARUN\Desktop\250lpa\env2\Lib\site-packages\tf_keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# ...

# %%
y_pred=model.predict(X_test)
# Out:
# 23/23 [==============================] - 16s 533ms/step

# %%
y_pred
# Out:
# array([[-4.9111133 , -3.3383906 , -2.1385489 ,  3.3462346 , -1.2247963 ],
#        [ 1.1419215 , -2.3311596 , -4.529752  , -3.3236895 , -0.53449416],
#        [ 7.768722  , -5.991756  , -7.2700734 , -1.8420703 ,  2.5007212 ],
#        ...,
#        [-5.820586  ,  3.0715795 , -0.91080105, -0.5481692 , -4.901616  ],
#        [-3.9676428 , -2.5359533 ,  2.259296  , -4.2384496 , -5.5814524 ],
#        [ 3.2574143 , -3.4654942 , -3.7927456 , -3.8403213 ,  0.43959698]],
#       dtype=float32)

# %%
y_prob = np.exp(y_pred) / np.sum(np.exp(y_pred), axis=1, keepdims=True)
y_prob
# Out:
# array([[2.5526021e-04, 1.2302910e-03, 4.0840637e-03, 9.8424608e-01,
#         1.0184277e-02],
#        [8.1102717e-01, 2.5159121e-02, 2.7916371e-03, 9.3249222e-03,
#         1.5169710e-01],
#        [9.9480498e-01, 1.0510861e-06, 2.9273323e-07, 6.6653629e-05,
#         5.1271282e-03],
#        ...,
#        [1.3142744e-04, 9.5610273e-01, 1.7822914e-02, 2.5613427e-02,
#         3.2945015e-04],
#        [1.9517863e-03, 8.1697190e-03, 9.8800105e-01, 1.4887521e-03,
#         3.8865447e-04],
#        [9.4105828e-01, 1.1321252e-03, 8.1615179e-04, 7.7823206e-04,
#         5.6215227e-02]], dtype=float32)

# %%
z=[]
for i in y_prob:
    predicted_label = int(np.argmax(i))  # Get the index of the highest probability
    print(flowers_labels_dict[predicted_label])  # Map and print the label
    z.append(flowers_labels_dict[predicted_label])

z
# Out:
# tulip
# rose
# rose
# dandelion
# tulip
# daisy
# rose
# sunflower
# daisy
# dandelion
# tulip
# tulip
# tulip
# dandelion
# dandelion
# tulip
# daisy
# dandelion
# sunflower
# dandelion
# sunflower
# tulip
# daisy
# sunflower
# sunflower
# rose
# rose
# dandelion
# dandelion
# rose
# rose
# rose
# sunflower
# rose
# daisy
# dandelion
# daisy
# dandelion
# rose
# rose
# sunflower
# dandelion
# sunflower
# dandelion
# sunflower
# dandelion
# sunflower
# sunflower
# rose
# dandelion
# dandelion
# sunflower
# rose
# dandelion
# tulip
# daisy
# rose
# daisy
# sunflower
# tulip
# sunflower
# tulip
# dandelion
# rose
# rose
# dandelion
# tulip
# rose
# dandelion
# dandelion
# rose
# daisy
# daisy
# tulip
# daisy
# tulip
# sunflower
# daisy
# tulip
# daisy
# tulip
# daisy
# daisy
# tulip
# sunflower
# sunflower
# sunflower
# daisy
# daisy
# daisy
# tulip
# rose
# tulip
# dandelion
# daisy
# tulip
# tulip
# tulip
# tulip
# sunflower
# sunflower
# dandelion
# dandelion
# sunflower
# tulip
# ...

# %%
y_test
for i in y_test:
    print(flowers_labels_dict[i])
# Out:
# tulip
# rose
# rose
# dandelion
# tulip
# daisy
# rose
# sunflower
# daisy
# dandelion
# tulip
# tulip
# sunflower
# dandelion
# dandelion
# tulip
# daisy
# dandelion
# dandelion
# rose
# sunflower
# tulip
# daisy
# sunflower
# sunflower
# rose
# tulip
# dandelion
# dandelion
# rose
# dandelion
# dandelion
# sunflower
# rose
# daisy
# dandelion
# daisy
# dandelion
# rose
# rose
# sunflower
# dandelion
# sunflower
# dandelion
# sunflower
# rose
# sunflower
# sunflower
# rose
# sunflower
# dandelion
# sunflower
# rose
# dandelion
# dandelion
# daisy
# rose
# daisy
# sunflower
# rose
# daisy
# tulip
# dandelion
# rose
# rose
# tulip
# tulip
# rose
# dandelion
# dandelion
# rose
# daisy
# daisy
# tulip
# daisy
# tulip
# sunflower
# daisy
# tulip
# daisy
# tulip
# daisy
# daisy
# tulip
# sunflower
# sunflower
# sunflower
# daisy
# daisy
# daisy
# tulip
# rose
# tulip
# rose
# daisy
# tulip
# tulip
# tulip
# tulip
# dandelion
# sunflower
# dandelion
# dandelion
# sunflower
# tulip
# tulip
# ...

# %%
print(flowers_labels_dict.keys())
# Out:
# dict_keys(['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips'])

# %%
flowers_labels_dict = {
    0: 'rose',
    1: 'daisy',
    2: 'sunflower',
    3: 'tulip',
    4: 'dandelion'
}
